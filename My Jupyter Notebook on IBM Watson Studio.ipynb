# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# ## Taylor Eidschun
# Data Scientist

# %% [markdown]
# *I am interested in Data Science, because I have always been curious about how things function and work and how I can improve them.*

# %% [markdown]
# ### A simple code to print the number 5.

# %%
x = 5
print('x')
# Out:
# x

# %% [markdown]
# | QBR        | Rating           | Overall |
# | ------------- |:-------------:| -----:|
# | 70      | 82 | 78 |
# | 80      | 94      |   86 |
# | 52 | 79     |    66 |

# %% [markdown]
# [I'm a basic ling](https://www.google.com)

# %% [markdown]
# ~~Always fix your mistakes~~
